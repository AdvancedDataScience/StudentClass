# %% [markdown]
# Student classification ML:
# from "student_admission_record_dirty.csv"

# %%
import numpy as np
import pandas as pd
import random as rd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
pd.options.mode.copy_on_write = True

# %%
clean_student = pd.read_csv("student.csv")

# %%
display(clean_student)
# Out:
#         Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0    Shehroz  24.0  Female                  50.0                   68.90
# 1      Waqar  21.0  Female                  99.0                   60.73
# 2     Bushra  17.0    Male                  89.0                     NaN
# 3      Aliya  17.0    Male                  55.0                   85.29
# 4      Bilal  20.0    Male                  65.0                   61.13
# ..       ...   ...     ...                   ...                     ...
# 152      Ali  19.0  Female                  85.0                   78.09
# 153    Bilal  17.0  Female                  81.0                   84.40
# 154   Fatima  21.0  Female                  98.0                   50.86
# 155   Shoaib  -1.0    Male                  91.0                   80.12
# 156     Maaz  17.0    Male                  88.0                   86.85
#
#           City Admission Status
# 0       Quetta         Rejected
# ...

# %%
#Cleaning data
#Remove NA rows
clean_student=raw_student.dropna()
display(clean_student)
#Recode Predicted to categories
clean_student['Sex'] = np.where(clean_student['Gender'] == "Male", 1, 0)
clean_student['Adm_recode'] = np.where(clean_student['Admission Status'] == "Accepted", 1, 0)

display(clean_student)
# Out:
#         Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0    Shehroz  24.0  Female                  50.0                   68.90
# 3      Aliya  17.0    Male                  55.0                   85.29
# 7      Rabia  20.0  Female                  82.0                   55.67
# 9     Kamran  18.0    Male                  53.0                   98.98
# 10    Shafiq  17.0    Male                  78.0                  -10.00
# ..       ...   ...     ...                   ...                     ...
# 152      Ali  19.0  Female                  85.0                   78.09
# 153    Bilal  17.0  Female                  81.0                   84.40
# 154   Fatima  21.0  Female                  98.0                   50.86
# 155   Shoaib  -1.0    Male                  91.0                   80.12
# 156     Maaz  17.0    Male                  88.0                   86.85
#
#           City Admission Status
# 0       Quetta         Rejected
# ...

# %%
#First step partition data
TrainSize=0.8
DevSize=0.1
TrainSize = int(TrainSize*len(clean_student))
DevSize=int(DevSize*len(clean_student))
TestSize=len(clean_student)-TrainSize-DevSize
print("Size of data; Train/Dev/Test {}/{}/{}.".format(TrainSize,DevSize,TestSize))
# Out:
# Size of data; Train/Dev/Test 80/10/10.

# %%
AllIndex=np.random.permutation(len(clean_student))
TrainIndex=AllIndex[0:TrainSize]
DevIndex=AllIndex[TrainSize:(TrainSize+DevSize)]
TestIndex=AllIndex[TrainSize+DevSize:]
TrainSet=clean_student.take(TrainIndex)
DevSet=clean_student.take(DevIndex)
TestSet=clean_student.take(TestIndex)
display(TestSet)
# Out:
#          Name   Age  Gender  Admission Test Score  High School Percentage  \
# 82   Muzammil  24.0  Female                  97.0                   62.68
# 62      Fahad  23.0    Male                  93.0                   90.35
# 54    Shehroz  22.0  Female                  72.0                   97.84
# 128   Zunaira  19.0  Female                  75.0                   63.03
# 63     Farhan  20.0  Female                  75.0                   79.59
# 142      Sana  22.0  Female                  91.0                   84.08
# 115     Maham  23.0    Male                  94.0                   87.05
# 88      Aliya  17.0    Male                  55.0                   85.29
# 13      Ahmed  21.0    Male                  62.0                   79.03
# 10     Shafiq  17.0    Male                  78.0                  -10.00
#
#            City Admission Status  Sex  Adm_recode
# 82       Lahore         Accepted    0           1
# 62     Peshawar         Accepted    1           1
# ...

# %%
X_Train=TrainSet.iloc[:,[1,3,4,7]] #Exclude Admission column
Y_Train=TrainSet.iloc[:,8]
X_Dev=DevSet.iloc[:,[1,3,4,7]] #Exclude Admission column
Y_Dev=DevSet.iloc[:,8]
X_Test=TestSet.iloc[:,[1,3,4,7]] #Exclude Admission column
Y_Test=TestSet.iloc[:,8]
display(X_Train)
display(Y_Train)
# Out:
#      Age  Admission Test Score  High School Percentage  Sex
# 44  19.0                  52.0                   78.67    0
# 52  21.0                  62.0                   79.03    1
# 46  24.0                  84.0                   94.33    0
# 22  18.0                  53.0                   98.98    1
# 94  22.0                  82.0                   78.30    1
# ..   ...                   ...                     ...  ...
# 79  19.0                  81.0                   67.75    0
# 80  18.0                  72.0                   67.51    0
# 36  24.0                  94.0                   98.43    1
# 60  19.0                  54.0                   52.79    0
# 26  20.0                  76.0                   69.27    0
#
# [80 rows x 4 columns]
# 44    1
# 52    1
# 46    1
# 22    0
# 94    1
#      ..
# 79    0
# 80    1
# 36    0
# 60    1
# 26    0
# Name: Adm_recode, Length: 80, dtype: int64

# %%
#KNN MODEL CREATION
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(X_Train, Y_Train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
#Showing result from Train set
Y_Pred_Train = knn.predict(X_Train)
Accuracy_Train = accuracy_score(Y_Train, Y_Pred_Train)
print("Accuracy from Training set:", Accuracy_Train)
# Out:
# Accuracy from Training set: 0.7875

# %%
#Test on Dev Set
Y_Pred_Dev = knn.predict(X_Dev)
Accuracy_Dev = accuracy_score(Y_Dev, Y_Pred_Dev)
print("Accuracy from Dev set:", Accuracy_Dev)
# Out:
# Accuracy from Dev set: 0.4

# %%
print("Training accuracy is {:.2f} while Dev. set accuracy is {:.2f}.".format(Accuracy_Train,Accuracy_Dev))
# Out:
# Training accuracy is 0.79 while Dev. set accuracy is 0.40.

# %%
print ("""
NEEDED OUTCOME =
Accuracy from Dev set: 0.5
Training accuracy is 0.787 while Dev. set accuracy is 0.400 ,and Test set accuracy is 0.500
""")
# Out:
# NEEDED OUTCOME =
# Accuracy from Dev set: 0.5
# Training accuracy is 0.787 while Dev. set accuracy is 0.400 ,and Test set accuracy is 0.500

# %%
#HOME WORK

# %%
#OPTIONAL 
#SVM
#XG_BOOST
#Random_Forrest
#HINT: https://www.datacamp.com/tutorial/k-nearest-neighbor-classification-scikit-learn
